# %% [markdown]
# <a href="https://colab.research.google.com/github/ianellisjones/usn/blob/main/Fleet_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
US NAVY FLEET TRACKER (IEJ)

A scraping utility to track the deployment history of the entire US Navy Surface Fleet.
Covers: CVN, LHA, LHD, LPD, LSD, LCC, CG, LCS, AS, ESB, and DDG.
"""

import csv
import re
from pathlib import Path
from typing import List, Tuple, Dict

import requests
from bs4 import BeautifulSoup

# --- CONFIGURATION ---

FLEET_URLS: List[str] = [
    # Aircraft Carriers (CVN)
    "http://uscarriers.net/cvn68history.htm", "http://uscarriers.net/cvn69history.htm",
    "http://uscarriers.net/cvn70history.htm", "http://uscarriers.net/cvn71history.htm",
    "http://uscarriers.net/cvn72history.htm", "http://uscarriers.net/cvn73history.htm",
    "http://uscarriers.net/cvn74history.htm", "http://uscarriers.net/cvn75history.htm",
    "http://uscarriers.net/cvn76history.htm", "http://uscarriers.net/cvn77history.htm",
    "http://uscarriers.net/cvn78history.htm",

    # Amphibious Assault (LHA/LHD)
    "http://uscarriers.net/lhd1history.htm", "http://uscarriers.net/lhd2history.htm",
    "http://uscarriers.net/lhd3history.htm", "http://uscarriers.net/lhd4history.htm",
    "http://uscarriers.net/lhd5history.htm", "http://uscarriers.net/lhd7history.htm",
    "http://uscarriers.net/lhd8history.htm", "http://uscarriers.net/lha6history.htm",
    "http://uscarriers.net/lha7history.htm",

    # Transport Docks (LPD)
    "http://uscarriers.net/lpd17history.htm", "http://uscarriers.net/lpd18history.htm",
    "http://uscarriers.net/lpd19history.htm", "http://uscarriers.net/lpd20history.htm",
    "http://uscarriers.net/lpd21history.htm", "http://uscarriers.net/lpd22history.htm",
    "http://uscarriers.net/lpd23history.htm", "http://uscarriers.net/lpd24history.htm",
    "http://uscarriers.net/lpd25history.htm", "http://uscarriers.net/lpd26history.htm",
    "http://uscarriers.net/lpd27history.htm", "http://uscarriers.net/lpd28history.htm",
    "http://uscarriers.net/lpd29history.htm",

    # Dock Landing Ships (LSD)
    "http://uscarriers.net/lsd44history.htm", "http://uscarriers.net/lsd46history.htm",
    "http://uscarriers.net/lsd50history.htm", "http://uscarriers.net/lsd51history.htm",
    "http://uscarriers.net/lsd42history.htm", "http://uscarriers.net/lsd45history.htm",
    "http://uscarriers.net/lsd47history.htm", "http://uscarriers.net/lsd48history.htm",
    "http://uscarriers.net/lsd49history.htm", "http://uscarriers.net/lsd52history.htm",

    # Command Ships (LCC)
    "http://uscarriers.net/lcc19history.htm", "http://uscarriers.net/lcc20history.htm",

    # Submarine Tenders (AS)
    "http://uscarriers.net/as39history.htm", "http://uscarriers.net/as40history.htm",

    # Expeditionary Sea Bases (ESB)
    "http://uscarriers.net/esb3history.htm", "http://uscarriers.net/esb4history.htm",
    "http://uscarriers.net/esb5history.htm", "http://uscarriers.net/esb6history.htm",

    # Guided Missile Cruisers (CG)
    "http://uscarriers.net/cg58history.htm", "http://uscarriers.net/cg60history.htm",
    "http://uscarriers.net/cg64history.htm", "http://uscarriers.net/cg67history.htm",
    "http://uscarriers.net/cg59history.htm", "http://uscarriers.net/cg65history.htm",
    "http://uscarriers.net/cg70history.htm", "http://uscarriers.net/cg71history.htm",
    "http://uscarriers.net/cg62history.htm",

    # Littoral Combat Ships (LCS)
    "http://uscarriers.net/lcs3history.htm", "http://uscarriers.net/lcs6history.htm",
    "http://uscarriers.net/lcs8history.htm", "http://uscarriers.net/lcs10history.htm",
    "http://uscarriers.net/lcs12history.htm", "http://uscarriers.net/lcs14history.htm",
    "http://uscarriers.net/lcs16history.htm", "http://uscarriers.net/lcs18history.htm",
    "http://uscarriers.net/lcs20history.htm", "http://uscarriers.net/lcs22history.htm",
    "http://uscarriers.net/lcs24history.htm", "http://uscarriers.net/lcs26history.htm",
    "http://uscarriers.net/lcs28history.htm", "http://uscarriers.net/lcs30history.htm",
    "http://uscarriers.net/lcs32history.htm", "http://uscarriers.net/lcs34history.htm",
    "http://uscarriers.net/lcs36history.htm", "http://uscarriers.net/lcs13history.htm",
    "http://uscarriers.net/lcs15history.htm", "http://uscarriers.net/lcs17history.htm",
    "http://uscarriers.net/lcs19history.htm", "http://uscarriers.net/lcs21history.htm",
    "http://uscarriers.net/lcs23history.htm", "http://uscarriers.net/lcs25history.htm",
    "http://uscarriers.net/lcs27history.htm", "http://uscarriers.net/lcs29history.htm",

    # Guided Missile Destroyers (DDG)
    "http://uscarriers.net/ddg51history.htm", "http://uscarriers.net/ddg52history.htm",
    "http://uscarriers.net/ddg53history.htm", "http://uscarriers.net/ddg54history.htm",
    "http://uscarriers.net/ddg55history.htm", "http://uscarriers.net/ddg56history.htm",
    "http://uscarriers.net/ddg57history.htm", "http://uscarriers.net/ddg58history.htm",
    "http://uscarriers.net/ddg59history.htm", "http://uscarriers.net/ddg60history.htm",
    "http://uscarriers.net/ddg61history.htm", "http://uscarriers.net/ddg62history.htm",
    "http://uscarriers.net/ddg63history.htm", "http://uscarriers.net/ddg64history.htm",
    "http://uscarriers.net/ddg65history.htm", "http://uscarriers.net/ddg66history.htm",
    "http://uscarriers.net/ddg67history.htm", "http://uscarriers.net/ddg68history.htm",
    "http://uscarriers.net/ddg69history.htm", "http://uscarriers.net/ddg70history.htm",
    "http://uscarriers.net/ddg71history.htm", "http://uscarriers.net/ddg72history.htm",
    "http://uscarriers.net/ddg73history.htm", "http://uscarriers.net/ddg74history.htm",
    "http://uscarriers.net/ddg75history.htm", "http://uscarriers.net/ddg76history.htm",
    "http://uscarriers.net/ddg77history.htm", "http://uscarriers.net/ddg78history.htm",
    "http://uscarriers.net/ddg79history.htm", "http://uscarriers.net/ddg80history.htm",
    "http://uscarriers.net/ddg81history.htm", "http://uscarriers.net/ddg82history.htm",
    "http://uscarriers.net/ddg83history.htm", "http://uscarriers.net/ddg84history.htm",
    "http://uscarriers.net/ddg85history.htm", "http://uscarriers.net/ddg86history.htm",
    "http://uscarriers.net/ddg87history.htm", "http://uscarriers.net/ddg88history.htm",
    "http://uscarriers.net/ddg89history.htm", "http://uscarriers.net/ddg90history.htm",
    "http://uscarriers.net/ddg91history.htm", "http://uscarriers.net/ddg92history.htm",
    "http://uscarriers.net/ddg93history.htm", "http://uscarriers.net/ddg94history.htm",
    "http://uscarriers.net/ddg95history.htm", "http://uscarriers.net/ddg96history.htm",
    "http://uscarriers.net/ddg97history.htm", "http://uscarriers.net/ddg98history.htm",
    "http://uscarriers.net/ddg99history.htm", "http://uscarriers.net/ddg100history.htm",
    "http://uscarriers.net/ddg101history.htm", "http://uscarriers.net/ddg102history.htm",
    "http://uscarriers.net/ddg103history.htm", "http://uscarriers.net/ddg104history.htm",
    "http://uscarriers.net/ddg105history.htm", "http://uscarriers.net/ddg106history.htm",
    "http://uscarriers.net/ddg107history.htm", "http://uscarriers.net/ddg108history.htm",
    "http://uscarriers.net/ddg109history.htm", "http://uscarriers.net/ddg110history.htm",
    "http://uscarriers.net/ddg111history.htm", "http://uscarriers.net/ddg112history.htm",
    "http://uscarriers.net/ddg113history.htm", "http://uscarriers.net/ddg114history.htm",
    "http://uscarriers.net/ddg115history.htm", "http://uscarriers.net/ddg116history.htm",
    "http://uscarriers.net/ddg117history.htm", "http://uscarriers.net/ddg118history.htm",
    "http://uscarriers.net/ddg119history.htm", "http://uscarriers.net/ddg120history.htm",
    "http://uscarriers.net/ddg121history.htm", "http://uscarriers.net/ddg122history.htm",
    "http://uscarriers.net/ddg123history.htm", "http://uscarriers.net/ddg125history.htm",
    # Zumwalt Class
    "http://uscarriers.net/ddg1000history.htm", "http://uscarriers.net/ddg1001history.htm",
    "http://uscarriers.net/ddg1002history.htm",
]

OUTPUT_FILENAME = "fleet_status.csv"
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'


def fetch_history_text(url: str, char_limit: int = 50000) -> str:
    try:
        response = requests.get(url, headers={'User-Agent': USER_AGENT}, timeout=20)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        full_text = soup.get_text(separator='\n')
        lines = [line.strip() for line in full_text.split('\n') if line.strip()]
        clean_text = '\n'.join(lines)
        return clean_text[-char_limit:] if len(clean_text) > char_limit else clean_text
    except requests.RequestException as e:
        return f"ERROR: {str(e)}"


def parse_status_entry(text_block: str) -> Tuple[str, str]:
    lines = text_block.split('\n')

    current_year = "Unknown"
    years_found = re.findall(r'(202[3-6])', text_block)

    if years_found:
        priority_years = [y for y in years_found if y in ['2024', '2025']]
        current_year = priority_years[-1] if priority_years else years_found[-1]

    processed_lines = []
    running_year = current_year

    for line in lines:
        year_match = re.search(r'^202[3-6]', line)
        if year_match:
            running_year = year_match.group(0)
        processed_lines.append({'text': line, 'year': running_year})

    keywords = [
        "moored", "anchored", "underway", "arrived", "departed",
        "transited", "operations", "returned", "participated", "conducted",
        "moved to", "visited", "pulled into", "sea trials", "flight deck certification",
        "undocked", "dry-dock"
    ]

    allowed_years = ["2024", "2025", "2026"]

    for entry in reversed(processed_lines):
        text_lower = entry['text'].lower()
        year = entry['year']

        if year in allowed_years and any(k in text_lower for k in keywords):
            if text_lower.strip().startswith("from ") and " - " in text_lower:
                continue
            return year, entry['text']

    return current_year, "No status found."


def categorize_location(text: str) -> str:
    """
    Maps status text to standardized high-level location tags.
    Logic: Last Occurrence Wins (Sorts by End Index).
    """
    text = text.lower()

    location_map = {
        # Movement Overrides
        "Pacific Ocean": ["departed san diego", "departed pearl harbor", "pacific ocean", "pacific", "departed bremerton", "departed everett", "departed seattle", "north pacific ocean"],
        "Atlantic Ocean": ["departed norfolk", "departed mayport", "atlantic ocean", "atlantic", "departed little creek", "off the coast of panama city", "north atlantic ocean"],

        # Major US Ports
        "San Diego": ["san diego", "north island", "camp pendleton", "nassco", "bae systems", "point loma", "a-175", "a-173", "seal beach"],
        "Norfolk": ["norfolk", "portsmouth", "virginia beach", "newport news", "little creek"],
        "Mayport": ["mayport", "jacksonville"],
        "Bremerton": ["bremerton", "kitsap"],
        "Everett": ["everett"],
        "Pearl Harbor": ["pearl harbor"],
        "Seattle": ["seattle", "vigor shipyard"],
        "Portland, OR": ["swan island", "portland", "oregon"],
        "Groton": ["groton"],
        "Kings Bay": ["kings bay"],
        "Maine": ["maine", "bar harbor"],

        # Shipyards/Industrial
        "Pascagoula": ["pascagoula", "ingalls"],
        "Mobile, AL": ["mobile", "austal"],
        "Pensacola": ["pensacola"],
        "Marinette": ["marinette"],
        "Philadelphia": ["philadelphia"],
        "Orange, TX": ["orange, texas", "orange, tx"],
        "Charleston, SC": ["charleston"],
        "Port Canaveral": ["port canaveral"],
        "Port Angeles": ["port angeles"],

        # Foreign Ports
        "Yokosuka": ["yokosuka"],
        "Sasebo": ["sasebo", "juliet basin"],
        "Yokohama": ["yokohama"],
        "Busan": ["busan", "south korea"],
        "Guam": ["guam", "apra"],
        "Singapore": ["singapore", "changi"],
        "Bahrain": ["bahrain", "manama"],
        "Dubai": ["dubai", "jebel ali"],
        "Qatar": ["qatar", "emiri", "mesaieed"],
        "Duqm": ["duqm", "d'uqm", "oman"],
        "Manila": ["manila", "subic", "philippines"],
        "Klang": ["malaysia", "klang"],
        "Brunei": ["brunei", "muara"],
        "Okinawa": ["okinawa"],
        "Thailand": ["gulf of thailand", "pattaya"],
        "Australia": ["perth", "fremantle", "brisbane", "sydney"],
        "Rota": ["rota", "spain"],
        "Italy": ["italy", "genoa", "naples", "augusta bay", "gaeta"],
        "Malta": ["valletta", "malta"],
        "Saipan": ["saipan"],
        "Diego Garcia": ["diego garcia"],
        "Souda Bay": ["souda bay", "crete"],

        # Regions
        "South China Sea": ["south china sea", "spratly", "luzon"],
        "Western Pacific": ["western pacific", "westpac", "san bernardino", "philippine sea", "sea of japan"],
        "Persian Gulf": ["persian gulf", "arabian gulf"],
        "Arabian Sea": ["arabian sea"],
        "Red Sea": ["red sea", "bab el-mandeb"],
        "Gulf of Oman": ["gulf of oman"],
        "Gulf of Aden": ["gulf of aden"],
        "Mediterranean": ["mediterranean", "adriatic", "gibraltar", "med sea"],
        "Caribbean Sea": ["caribbean", "st. croix", "trinidad", "tobago", "puerto rico", "virgin islands", "st. thomas"],
        "North Sea": ["north sea", "norwegian sea", "oslo"],
        "Suez Canal": ["suez"],
        "Panama Canal": ["panama canal"],

        # Oceans
        "Indian Ocean": ["indian ocean"],
    }

    matches = []

    for label, keywords in location_map.items():
        for k in keywords:
            start_index = text.rfind(k)
            if start_index != -1:
                end_index = start_index + len(k)
                matches.append((end_index, len(k), label))

    if matches:
        matches.sort(key=lambda x: (x[0], x[1]), reverse=True)
        return matches[0][2]

    return "Underway / Unknown"


def extract_date(text: str) -> str:
    pattern = r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*\.?\s+\d{1,2}'
    matches = re.findall(pattern, text, re.IGNORECASE)
    return matches[-1] if matches else "Date Unspecified"


def main():
    print(f"{'='*90}")
    print(f"US NAVY TOTAL FLEET TRACKER (COMPLETE SURFACE FORCE)")
    print(f"{'='*90}\n")

    results: List[Dict[str, str]] = []

    for url in FLEET_URLS:
        # Updated Regex to include DDG
        hull_match = re.search(r'((?:cvn|lha|lhd|lpd|lsd|lcc|cg|lcs|as|esb|ddg)\d+)', url, re.IGNORECASE)
        hull = hull_match.group(1).upper() if hull_match else "UNK"

        raw_text = fetch_history_text(url)

        if "ERROR" in raw_text:
            year, status, loc_tag, date_str = "Error", raw_text, "Error", "Error"
        else:
            year, status = parse_status_entry(raw_text)
            loc_tag = categorize_location(status)
            date_str = extract_date(status)

            if date_str == "Date Unspecified":
                date_str = year

        results.append({
            "Hull": hull,
            "Location": loc_tag,
            "Date": date_str,
            "Status Sentence": status,
            "Source URL": url
        })

        print(f"[{hull}] [{loc_tag}] [{date_str}] {status}")

    try:
        output_path = Path(OUTPUT_FILENAME)
        with output_path.open(mode='w', newline='', encoding='utf-8') as csvfile:
            fieldnames = ["Hull", "Location", "Date", "Status Sentence", "Source URL"]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(results)

        print(f"\n{'='*90}")
        print(f"SUCCESS: Report saved to '{output_path.absolute()}'")
        print(f"{'='*90}")

    except PermissionError:
        print(f"\nERROR: Could not write to {OUTPUT_FILENAME}. Is the file open?")

if __name__ == "__main__":
    main()
# Out:
# ==========================================================================================
# US NAVY TOTAL FLEET TRACKER (COMPLETE SURFACE FORCE)
# ==========================================================================================
#
# [CVN68] [Western Pacific] [Nov. 18] From November 8-11, the Nimitz CSG conducted operations  off the coast of Brunei; Conducted operations northeast of Spratly Islands from Nov. 12-13; Conducted operations off the southwest coast of Luzon from Nov. 14-17; Transited the San Bernardino Strait northbound on Nov. 18.
# [CVN69] [Norfolk] [Jan. 8] September 26, USS Dwight D. Eisenhower moored at Pier 12N on Naval Station Norfolk after a six-day underway for TRACOM-CQ, in the Jacksonville Op. Area; Moved "dead-stick" to Super Pier 5N in Norfolk Naval Shipyard, for a Planned Incremental Availability (PIA), on Jan. 8.
# [CVN70] [San Diego] [September 16] September 16, The Carl Vinson moored at Juliet Pier on Naval Air Station North Island after a three-day underway for ammo offload.
# [CVN71] [San Diego] [Nov. 10] November  8, USS Theodore Roosevelt moored at Berth Lima on Naval Air Station North Island   after a 12-day underway for Tailored Ship's Training Availability (TSTA) and Final Evaluation Problem (FEP), with the Carrier Air Wing (CVW) 11; Underway again from Nov. 10-21.
# [CVN72] [Pacific Ocean] [2025] , USS Abraham Lincoln departed San Diego for a scheduled deployment.
# [CVN73] [South China Sea] [Nov. 22] From November 19-21, the George Washington CSG conducted operations northeast of Spratly Islands; Conducted operations off the southwest coast of Luzon on Nov. 22.
# [CVN74] [Norfolk] [April 8] April 8, 2024 USS John C. Stennis undocked and moored at Outfitting Berth #1 on Newport News Shipyard.
# [CVN75] [Norfolk] [Oct. 8] September 26, The Harry S. Truman moored at Pier 14S on Naval Station Norfolk; Moved to Pier 14N on Sept. 28; Brief underway  on Oct. 8.
# [CVN76] [Bremerton] [Dec. 2] November 12,  USS Ronald Reagan moored at Bravo Pier on Naval Base Kitsap-Bremerton; Underway for FRS-CQ, in the SOCAL Op. Area, from Dec. 2-13.
# [CVN77] [Mayport] [November 13] November 13, USS George H.W. Bush moored at Pier 11S on Naval Station Norfolk after a 10-day underway for FRS/TRACOM CQ, in the Virginia Capes and Jacksonville Op. Areas.
# [CVN78] [Caribbean Sea] [Nov. 16] November 13, USS Gerald R. Ford participated in a PHOTOEX with the USS Mahan, USS Winston S. Churchill and USS Bainbridge (DDG 96), while underway as a "show of force" approx. 200 n.m. northeast of Puerto Rico; Transited the Anegada Passage southbound on Nov. 16; Conducted operations south of Puerto Rico from Nov. 16-22.
# [LHD1] [San Diego] [May 19] April 14, USS Wasp moored at Berth 6, Pier 11 on Naval Station Norfolk after a 10-day underway for deck landing qualifications, in the Virginia Capes Op. Area; Underway again on April 28; Moored at Berth 6, Pier 6 on May 9; Moved "dead-stick" to Pier 1 in BAE Systems shipyard on May 19.
# [LHD2] [San Diego] [Oct. 9] October 6, USS Essex departed Naval Base San Diego for sea trials following an extended 37-month availability; Anchored at A-173 for a brief stop before moored at Berth 5, Pier 2 on Oct. 9.
# [LHD3] [Norfolk] [Nov. 14] September 26, USS Kearsarge moved from Pier 12 to Berth 3, Pier 14 on Naval Station Norfolk; Moved  to Berth 4, Pier 14 on Sept. 28; Underway again on Oct. 8; Moored at Berth 1, Pier 12 on Oct. 10; Underway in the Virginia Capes Op Area from Oct. 16-22 and Nov. 14-21.
# [LHD4] [San Diego] [Nov. 12] November 4, USS Boxer moored at Berth 6, Pier 13 on Naval Base San Diego for a brief stop; Returned home on Nov. 12.
# [LHD5] [San Diego] [2025] July ?, 2025 USS Bataan undocked and moored at  Berth 2E on NASSCO shipyard.
# [LHD7] [Caribbean Sea] [Nov. 18] November 6, The Iwo Jima moored at Ann E. Abramson Marine Facility in Frederiksted,  St. Croix, U.S. Virgin Islands, for a four-day port call; Conducted a replenishment-at-sea with the USNS Kanawha (T-AO 196) on Nov. 14; Conducted operations approx. 40 n.m. northwest  of Trinidad and Tobago from Nov. 18-21.
# [LHD8] [San Diego] [Nov. 10] October 18, USS Makin Island participated in Amphibious Capabilities Demonstration, in conjunction with the Marine Corps 250th birthday, off the coast of Camp Pendleton; Moored at Berth 5, Pier 8 on Oct. 21; Underway again from Nov. 10-13.
# [LHA6] [San Diego] [2025] , USS America moored at Berth 5, Pier 13 in its new homeport of Naval Base San Diego after forward-deployed to Japan for nearly six years.
# [LHA7] [Sasebo] [Oct. 29] October 24, The Tripoli moored at Navy Pier East on White Beach Naval Facility in Okinawa for a two-day port call; Transited the Osumi Strait westbound on Oct. 28; Moored at Berth 3, Juliet Basin Wharf on Oct. 29.
# [LPD17] [Caribbean Sea] [November 21] November 21, USS San Antonio moored at Austin Monsanto North Side Marine Terminal in Crown Bay, St. Thomas Island, U.S. Virgin Islands, for a two-day liberty port visit.
# [LPD18] [Sasebo] [October 29] October 29, USS New Orleans moored at Berth 1, Juliet Basin Wharf on Fleet Activities Sasebo.
# [LPD19] [Norfolk] [2025] , USS Mesa Verde moored at Berth 2, Pier 12 on Naval Station Norfolk following an extended eight-and-a-half month deployment in the U.S. 6th Fleet AoR.
# [LPD20] [San Diego] [July 21] July 21, The Green Bay undocked and moored at Pier 4N on BAE Systems shipyard.
# [LPD21] [Norfolk] [Sept. 2] July 16, USS New York moored at   Berth 2, Pier 12 on Naval Station Norfolk; Moved "dead-stick" to Berth 2, Midtown Pier at Marine Hydraulics Industries (MHI) Ship Repair & Services shipyard in Norfolk on Sept. 2.
# [LPD22] [Sasebo] [November 7] November 7, The San Diego moored at Berth 1, India Basin on Fleet Activities Sasebo.
# [LPD23] [San Diego] [November 21] November 21, USS Anchorage moored at Berth 5, Pier 4 on Naval Base San Diego after a four-day underway in the SOCAL Op. Area.
# [LPD24] [Norfolk] [November 19] November 19, USS Arlington moored at Berth 2, Pier 9 on Naval Station Norfolk after a one-day underway off the coast of Virginia.
# [LPD25] [San Diego] [Nov. 2] August 23,  USS Somerset  moored at Berth 2, Pier 8 on Naval Base San Diego; Moved "dead-stick" to Pier 3N in BAE Systems shipyard on Oct. 3; Entered the Pride of California Dry Dock on Nov. 2.
# [LPD26] [San Diego] [Sept. 22] September 8, LPD 26 anchored at A-175 for an overnight stop before underway off the coast of southern California; Anchored at A-175 again from Sept. 9-10; Moored at Berth 5, Pier 7 on Sept. 11; Moved to Berth 1, Pier 6 on Sept. 22.
# [LPD27] [San Diego] [Nov. 12] October 29, LPD 27 moored at Navy Fuel Farm (NFF)  on Naval Base Point Loma for a brief stop to refuel; Moored at Berth 1. Pier 12 on Nov. 12.
# [LPD28] [Caribbean Sea] [Nov. 15] November 8, USS Fort Lauderdale moored at Berth 2/3 in Port of Ponce, Puerto Rico, for a three-day visit; Transited the Martinique Passage eastbound on Nov. 15.
# [LPD29] [Norfolk] [November 19] November 19, The McCool moored at Berth 2, Pier 10 on Naval Station Norfolk, around 2:10 p.m., after suffered an engineering casualty shortly after underway at 1:10 p.m. local time.
# [LSD44] [Atlantic Ocean] [Nov. 17] October 25, The Gunston Hall anchored off the coast of Camp Lejeune, N.C., for a one-day stop; Moored at Berth 6, Pier 2 on Oct. 27; Underway again on Nov. 7; Anchored 15 n.m. off the coast of Panama City, Fla., to embark new LCACs, from Nov. 12-13; Moored at Berth 6, Pier 2 on Nov. 17.
# [LSD46] [Norfolk] [May 20] November 14, 2017 BAE Systems Norfolk Ship Repair was awarded a $139,8 milion contract for the USS Tortuga's Chief of Naval Operations (CNO) availability. This contract includes options which, if exercised, would bring the cumulative value of this contract to $183,8 milion and the work is expected to be completed by May 2019.
# [LSD50] [San Diego] [April 29] April 29, 2025 USS Carter recently undocked and moored at Pier 3S on BAE Systems shipyard.
# [LSD51] [San Diego] [Aug. 25] August 18, USS Oak Hill moored at Berth 2, Pier 2 on Naval Station Norfolk; Moved "dead-stick" to Pier 1E at NASSCO shipyard on Aug. 25.
# [LSD42] [San Diego] [Nov. 13] October 10,  USS Germantown moored at Berth 2, Pier 10 on Naval Base San Diego; Underway again on Oct. 15; Moored at NWS Seal Beach for ammo offload from Oct. 16-17; Returned home on Oct. 18; Moved to Berth 1/2, Broadway Pier in downtown San Diego  for  Fleet Week on Nov. 5; Underway on Nov. 12; Moored at Berth 2, Pier 10 on Nov. 13.
# [LSD45] [San Diego] [Nov. 12] November 7,  The Comstock moored at NFF on Naval Base Point Loma for a brief stop to refuel; Moored at Berth 2, Pier 12 on Nov. 12.
# [LSD47] [Sasebo] [Oct. 1] , USS Rushmore moored at Berth 1, Juliet Basin Wharf on  Fleet Activities Sasebo following a two-and-a-half month patrol; Anchored at A-39 in Sasebo Harbor   on Sept. 29; Moored at Berth 7, India Basin on Oct. 1.
# [LSD48] [San Diego] [Nov. 10] November 7, USS Ashland moored at Berth 1, Pier 8 on Naval Base San Diego after a three-day underway in the SOCAL Op. Area; Moored at NFF for a brief stop to refuel before underway again on Nov. 10.
# [LSD49] [San Diego] [July 28] July 1,  The Harpers Ferry moored at Berth 6, Pier 7 on Naval Base San Diego after a one-day underway in the SOCAL Op. Area; Moved "dead-stick" to Berth 4 in NASSCO shipyard on July 28.
# [LSD52] [San Diego] [Nov. 7] October 20,  The Pearl Harbor  moored at Berth 1, Pier 8 on Naval Base San Diego after a four-day underway in the SOCAL Op. Area; Underway again on Nov. 3; Moored at NWS Seal Beach for ammo offload from Nov. 4-6; Moored at Berth 6, Pier 6 on Nov. 7.
# [LCC19] [Yokosuka] [Nov. 17] October 6, USS Blue Ridge moored at Berth 9 on Fleet Activities Yokosuka; Underway again on Nov. 17.
# [LCC20] [Italy] [October 30] October 30, USS Mount Whitney moored at Dry Dock #4   on San Giorgio del Porto  shipyard in Port of Genoa, Italy, for a scheduled maintenance availability.
# [AS39] [Guam] [Oct. 20] May 20, The Emory S. Land moored at Alpha Wharf in Apra Harbor after a brief underway off the coast of Guam; Moved to Uniform Wharf for a brief stop on May 22; Underway again from Oct. 20-22.
# [AS40] [Pacific Ocean] [2025] , USS Frank Cable moored at Uniform Wharf in Apra Harbor following a  four-month Indo-Pacific patrol.
# [ESB3] [Malta] [Aug. 2] May 5,  USS Lewis B. Puler (Gold) moored at Berth K14 in its new administrative homeport of Souda Bay, Greece, for a routine port call; Moored at Parlatorio Wharf, Palumbo Shipyard in Port of Valletta, Malta, for a Mid-term Availability (MTA), on May 27; Entered the Dry Dock #6 on June 21; Undocked and moored at Parlatorio Wharf on Aug. 2?.
# [ESB4] [Norfolk] [2025] , USS Hershel "Woody" Williams (Gold) moored at Berth 1, Pier 7 in its new administrative homeport of Naval Station Norfolk after forward-deployed to Europe for nearly five years.
# [ESB5] [Underway / Unknown] [November 9] November 9, The Miguel Keith moored at Berth 6/7, Harbour Terminal in Port of Sriracha, Thailand, for a Mid-term Availability (MTA).
# [ESB6] [Underway / Unknown] [Nov. 7] October 21,  USS John L. Canley (Gold), commanded by Capt. Michael J. Welgan, anchored  1 n.m. off the coast of Apia, Samoa, for a 12-day port visit; Anchored off the coast of Luganville, Espiritu Santo, Republic of Vanuatu, from Nov. 7-16.
# [CG58] [Philadelphia] [October 20] October 20, The ex-USS Philippine Sea departed Naval Station Norfolk, under tow by tug Mary Emma, en route to Naval Inactive Ship Maintenance Facility in Philadelphia, Pa.
# [CG60] [Norfolk] [Sept. 9] September 4, USS Normandy moored at Pier 7N on Fort Trumbull State Park in New London, Conn., for a four-day port visit in conjunction with the annual Connecticut Maritime Heritage Festival; Moored at Berth 2, Pier 2 in Naval Station Norfolk on Sept. 9.
# [CG64] [Caribbean Sea] [Nov. 14] October 24, The Gettysburg moored at Wharf B2 on Naval Station Mayport for a three-day port call; Moored at Berth 8 in Port of Ponce, Puerto Rico, to refuel from Nov. 4-5; Transited eastbound, approx. 20 n.m. south of Curacao, overseas territory of Netherlands, on Nov. 13; Transited northbound, approx. 20 n.m. east of Orchila Island, Venezuela, just after midnight on Nov. 14.
# [CG67] [Pearl Harbor] [Nov. 18] August 1, The Shiloh moved from Bravo Wharf to Pier B11 on Pearl Harbor Naval Shipyard; Moved to Wharf B25 on Nov. 18.
# [CG59] [San Diego] [Sept. 19] September 17, The Princeton departed Naval Base San Diego for routine operations; Moored at Bravo Pier for a brief stop on Sept. 18; Moored at Berth 1, Pier 10 on Sept. 19.
# [CG65] [San Diego] [November 21] November 21, USS Chosin moored at Berth 6, Pier 7 on Naval Base San Diego.
# [CG70] [Caribbean Sea] [Nov. 10] September 19, The Lake Erie conducted a replenishment-at-sea with the USNS Joshua Humphreys, while underway south of Puerto Rico; Moored at Berth 8 in Port of Ponce again from Sept. 25-28; Moored at Berth 4 in Port of Ponce from Oct. 30- Nov. 1; Moored at Ann E. Abramson Marine Facility in Frederiksted, St. Croix, U.S. Virgin Islands, for upkeep from Nov. 10-24.
# [CG71] [San Diego] [Oct. 9] August 18, USS Cape St. George moored at Berth 6, Pier 8 on Naval Base San Diego after a four-day underway for sea trials; Moored at Berth 5, Pier 10 after a brief underway  on Sept. 24; Moored at NFF for a brief stop to refuel before underway again on Sept. 29; Moored at NFF  for a brief stop on Oct. 8; Returned home on Oct. 9.
# [CG62] [Busan] [November 5] November 5, USS Robert Smalls moored at Berth 2 in Busan Naval Base, Republic of Korea, for a four-day port visit.
# [LCS3] [San Diego] [Oct. 6] April 21, 2022 The Fort Fort moved from Pier 4 to Berth 2, Pier 1 on Naval Base San Diego; Underway again from May 31- June 1; Moved to Quay Wall 2 on Aug. 26; Moved to Berth 2, Pier 1 on Oct. 6.
# [LCS6] [San Diego] [Oct. 16] June 13, USS Jackson  moored at Berth 2, Pier 4 on Naval Base San Diego; Underway again from June 16-20 and Sept. 23-25; Moored at Bravo Pier for a brief stop to onload ammo before underway on Oct. 15; Moored at Berth 2, Pier 4 on Oct. 16.
# [LCS8] [San Diego] [November 6] November 6, USS Montgomery moored at Berth 5, Pier 5 on Naval Base San Diego after a brief underway for sea trials.
# [LCS10] [Seattle] [June 27] June 27, USS Gabrielle Giffords moored at Pier 6W on Vigor Shipyard in Seattle, Washington.
# [LCS12] [San Diego] [2025] , USS Omaha moored at Berth 2, Pier 6 on Naval Base San Diego following an 11-month deployment.
# [LCS14] [San Diego] [March 18] February 21, 2025 USS Manchester moored at Berth 2, Pier 5 on Naval Base San Diego after a three-day underway in the SOCAL Op. Area; Day-long underway  on Feb. 25; Moved to Quay Wall 3 on March 3; Moved to  Bravo Pier for a brief stop to offload ammo before moored at Berth 6, Pier 4 on March 18.
# [LCS16] [Bahrain] [Oct. 10] September 13, USS Tulsa moored at Berth 11, Mina Salman Port in Manama, Bahrain, its forward-deployed base of operations, for the first time; Underway for routine training, northeast of Bahrain, on Sept. 25; Moored at Berth 10, Deep Water Jetty, Mina Salman Port on Sept. 28; Underway again on Oct. 7; Moored at Berth 11, Mina Salman Port on Oct. 10.
# [LCS18] [San Diego] [November 12] November 12, The Charleston moored at Berth 5, Pier 6 on Naval Base San Diego after a 19-day underway in support of the USS Boxer (LHD 4) ARG's Surface Warfare Advanced Tactical Training (SWATT) exercise.
# [LCS20] [Brunei] [October 22] October 22, The Cininnati  moored at Conventional Terminal in Port of Muara, Brunei, for the in-port phase of annual Cooperation Afloat Readiness and Training (CARAT) exercise.
# [LCS22] [San Diego] [Oct. 7] August 25, USS Kansas City moored at Berth 6, Pier 4 on Naval Base San Diego; Underway again from Sept. 3-4 and Sept. 5; Moored at NFF for a brief stop to refuel on Sept. 12; Returned home on Sept. 15; Underway again from Sept. 19-22, Sept. 24-26 and Oct. 7-8.
# [LCS24] [San Diego] [October 28] October 28, 2025 USS Oakland moored at Berth 6, Pier 5 on Naval Base San Diego after a one-day underway for sea trials, following a 21-month Drydocking Selected Restricted Availability (DSRA).
# [LCS26] [San Diego] [2025] , USS Mobile moored at Berth 5, Pier 5 on Naval Base San Diego following a 20-month deployment.
# [LCS28] [San Diego] [Oct. 28] August 11, The Savannah departed Naval Base San Diego to offload ammunition; Moored at NWS Seal Beach from Aug. 12-14; Moored at Berth 2, Pier 6 on Aug. 15; Underway again from Sept. 8-17, Oct. 16-21 and Oct. 28-29.
# [LCS30] [Qatar] [July 21] July 21, The Canberra recently moored at  Qatari Emiri Naval Forces Base in Hamad Port, near Mesaieed, for a scheduled visit.
# [LCS32] [Persian Gulf] [Oct. 12] October 9, The Santa Barbara moored at Berth 13, Mina Salman Port after underway in the Arabian Gulf; Underway again on Oct. 12.
# [LCS34] [San Diego] [Nov. 20] November 18, LCS 34 moored at Naval Weapons Station Seal Beach for a one-day ammo onload; Moored at Berth 1, Pier 4 on Nov. 20.
# [LCS36] [San Diego] [Nov. 17] October 17, USS Kingsville moored at Berth 5, Pier 5 on Naval Base San Diego; Underway again from Oct. 21-22 and Oct. 27; Brief stop at NFF  to refuel before moored at Berth 5, Pier 6 on Oct. 30; Underway again from Nov. 12-14 and Nov. 17-21.
# [LCS13] [Mayport] [Nov. 20] November 3, USS Wichita moored at Wharf D3 on Naval Station Mayport; Moved to Wharf C2 for a brief stop before underway again on Nov. 13;  Moored at Berth 8 in Port of Ponce from Nov. 20-21.
# [LCS15] [Mayport] [Nov. 5] October 18, The Billings moored at Wharf C2 on Naval Station Mayport; Moved to Wharf D3 on Oct. 21; Underway again on Nov. 3; Moored outboard the USS Minneapolis-St. Paul (LCS 21) at Wharf D2 on Nov. 5.
# [LCS17] [Mayport] [2025] , USS Indianapolis  moored at Wharf C2 on Naval Station Mayport following a nearly 21-month deployment in the U.S. 5th and 6th Fleet Areas of Responsibility (AoR).
# [LCS19] [Mayport] [2025] , USS St. Louis moored at Wharf D1 on Naval Station Mayport following a three-month deployment in the U.S. 4th Fleet AoR.
# [LCS21] [Mayport] [2025] , USS Minneapolis-St. Paul moored at Wharf D2 on Naval Station Mayport following a six-and-a-half month deployment in the U.S. 4th Fleet AoR.
# [LCS23] [Mayport] [Nov. 13] October 20, The Cooperstown moored outboard the USS Indianapolis (LCS 17) at Wharf E3 on Naval Station Mayport; Brief underway  on Nov. 13.
# [LCS25] [Mayport] [February 2] February 2?, USS Marinette moored at BAE Systems Jacksonville Ship Repair facility on Fanning Island for a Post Shakedown Availability (PSA).
# [LCS27] [Mayport] [July 21] July 21, USS Nantucket entered the floating dry-dock at BAE Systems Jacksonville Ship Repair facility on Fanning Island for a Post Shakedown Availability (PSA).
# [LCS29] [Mayport] [Aug. 1] March 21, USS Beloit moved  from Echo Wharf to Wharf D3, outboard the USS Wichita (LCS 13), on Naval Station Mayport; Moored at Wharf D3 on March 2?; Moved to Wharf E2 on Aug. 1.
# [DDG51] [Rota] [2025] ,  USS  Arleigh Burke moored at Berth 2, Pier 1 on Naval Station Rota after more than a three-month patrol.
# [DDG52] [Everett] [Aug. 1] February ?, 2025 USS Barry undocked and moored at Pier 5E on Vigor Shipyards; Moved "dead-stick" to Berth 2, Alpha Pier in Naval Station Everett on Aug. 1?.
# [DDG53] [Everett] [Nov. 10] October 6,  USS John Paul Jones moored at Berth 6, Alpha Pier on Naval Station Everett; Underway again on Oct. 26; Moored at Wharf 3 in Port Hueneme, Calif., from Oct. 31- Nov. 7; Moored at Berth 6, Bravo Pier on Nov. 10.
# [DDG54] [San Diego] [2025] , USS Curtis Wilbur moored at Berth 2, Pier 13 on Naval Base San Diego following a seven-month deployment in the U.S. 7th Fleet AoR.
# [DDG55] [Norfolk] [November 17] November 17,  USS Stout moored at Berth 1, Pier 6 on Naval Station Norfolk.
# [DDG56] [Portland, OR] [February 10] February 10, 2025 USS John S. McCain moored at Berth 314, Swan Island Ship Repair Yard in Port of Portland, Ore., for a Drydocking Selected Restricted Availability (DSRA); Entered the Dry Dock #3 on Feb. ?.
# [DDG57] [Bahrain] [Oct. 2] October 20, The Mitscher conducted a replenishment-at-sea with the USNS Cesar Chavez (T-AKE 14), while underway in the Arabian Gulf; Moored at Mina Salman Port in Manama, Bahrain, from Oct. 2?-28.?
# [DDG58] [San Diego] [Feb. 10] November 21,  USS Laboon moored at Berth 1, Pier 2 on Naval Station Norfolk after a three-day underway in the Virginia Capes Op. Area; Moved "dead-stick" to Old Dominion Drydock in BAE Systems shipyard on Feb. 10, 2025.
# [DDG59] [San Diego] [June 11] June 11, The Russell moved "dead-stick" from Pier 7 to graving dry-dock at 32nd Street on Naval Base San Diego.
# [DDG60] [San Diego] [Nov. 21] October 10, USS Paul Hamilton moored at  Berth 5, Pier 7 on Naval Base San Diego; Moored at Bravo Pier for a brief stop to onload ammo before underway  on Nov. 17; Conducted Surface Ship Radiated Noise Measurement (SSRNM) testing, off the northeast coast of San Clemente Island, on Nov. 19; Returned home on Nov. 21.
# [DDG61] [Mayport] [March 7] March 7, 2025 USS Ramage undocked and moored at Wharf F1 on Naval Station Mayport; Moved to Wharf E1 on March ?.
# [DDG62] [Guam] [Nov. 13] October 30, The Fitzgerald conducted a replenishment-at-sea with the HMNZS Aotearoa (A11), while underway southwest of Luzon, Philippines; Brief stop at Echo Fueling Pier in Apra Harbor  before moored at Wharf ? on Nov. 7; Underway for at-sea phase of exercise Malabar 25 on Nov. 13.
# [DDG63] [San Diego] [November 5] November 5, The Stethem moored at Berth 5, Pier 3 on Naval Base San Diego after a two-day underway in the SOCAL Op. Area.
# [DDG64] [Mayport] [Nov. 6] October 17, USS Carney moored at Wharf D1 on Naval Station Mayport after a four-day underway in the Jacksonville Op. Area; Underway again on Oct. 27; Moored outboard the USS John Basilone (DDG 122) at Wharf D1 on Oct. 30; Moved to Wharf F2 on Nov. 6.
# [DDG65] [San Diego] [Nov. 17] November 7, The Benfold moored at Pier M2 on Joint Base Pearl Harbor-Hickam, Hawaii, for a two-day port call; Moored at Navy Fuel Farm (NFF) on Naval Base Point Loma for a brief stop to refuel on Nov. 14; Moored at Naval Weapons Station Seal Beach, Calif., for ammo offload from Nov. 17-20.
# [DDG66] [Norfolk] [Oct. 14] October  8, USS Gonzalez moored at Berth 2, Pier 14 on Naval Station Norfolk  after an eight-day underway, in support of the "Titans of the Sea" Presidential Review, off the coast of Virginia; Moved to Berth 1, Pier 4 on Oct. 14.
# [DDG67] [Mayport] [Nov. 18] October 16, USS Cole moored at Berth 6, Pier 5 on Naval Station Norfolk after a one-day underway in the Virginia Capes Op. Area; Underway for Task Force Exercise (TFEX) 26-2, in the Cherry Point and Jacksonville Op. Areas, on Oct. 24; Conducted operations off the coast of Virginia from Nov. 14-17; Returned home on Nov. 18.
# [DDG68] [Mayport] [2025] , USS  The Sullivans moored at Wharf B1 on Naval Station Mayport after more than an eight-month deployment in the U.S. 5th and 6th Fleet AoR.
# [DDG69] [Busan] [Nov. 5] October 30, USS Milius moored outboard the USS Dewey (DDG 105) at Berth 7 on Fleet Activities Yokosuka for a brief stop; Moored at Berth 6 in Busan Naval Base, ROK, from Nov. 5-9.
# [DDG70] [Pearl Harbor] [Nov. 7] October 30,  The Hopper moored at Wharf B22 on Joint Base Pearl Harbor-Hickam after a two-day underway in the Hawaiian Islands Op. Area; Moored at Wharf B23 after a brief underway  on Nov. 6; Underway again from Nov. 7-10.
# [DDG71] [Norfolk] [Nov. 12] November 5, The Ross moored at Berth 1, Pier 5 on Naval Station Norfolk after a four-day underway in the Virginia Capes and Narragansett Bay Op. Areas; Underway again from Nov. 12-14.
# [DDG72] [Caribbean Sea] [Nov. 22] November 16, USS Mahan transited the Anegada Passage southbound in support of national tasking; Conducted a replenishment-at-sea with the USNS Kanawha (T-AO 196), while underway south of Puerto Rico, on Nov. 17; Conducted maritime interoperability exercises with the GDFS Shahoud (1039), while underway off the east coast of Guyana, on Nov. 22.
# [DDG73] [San Diego] [Nov. 4] October 14, USS Decatur moored at Berth 6, Pier 3 on Naval Base San Diego; Moved to NFF for a brief stop to refuel on Oct. 20; Underway in support of the USS Boxer (LHD 4) ARG's SWATT exercise and Group Sail, as part of the USS Theodore Roosevelt (CVN 71) CSG, on Oct. 28; Moored at Bravo Pier for a brief stop to onload ammo on Oct. 29; Moored at NFF for a brief stop to refuel on Oct. 31, Nov. 4 and 12th.
# [DDG74] [Mayport] [Nov. 14] October 14, The McFaul moored at Weapons Pier R3 South on Naval Weapons Station Yorktown for a three-day ammo onload; Moored at Berth 5, Pier 6 on Oct. 17; Underway for Task Force Exercise (TFEX) 26-2, in the Cherry Point and Jacksonville Op. Areas, on Oct. 23; Moored at Berth 5, Pier 5 on Nov. 14.
# [DDG75] [Mayport] [October 7] October 7, USS Donald Cook moored at Wharf B3 on Naval Station Mayport.
# [DDG76] [Yokosuka] [Oct. 8] , USS Higgins moored at HMP East on Fleet Activities Yokosuka following a three-month patrol; Moved to Berth 6, outboard the USS Rafael Peralta (DDG 115), on Oct. 1; Anchored at A-10 for ammo offload on Oct. 6; Moored at Berth 6 on Oct. 8.
# [DDG77] [San Diego] [Oct. 27] August 11, USS O'Kane moored at Berth 2, Pier 3 on Naval Base San Diego for a brief stop; Arrived in the Gulf of Alaska, in support of   exercise Northern Edge 2025, on Aug. 17; Moored at Berth 1, Pier 3 on Aug. 28; Underway again on Oct. 17; Moored at NWS Seal Beach for ammo offload from Oct. 21-25; Returned home on Oct. 27.
# [DDG78] [San Diego] [May 5] April 16,  USS Porter moored at Berth 2, Pier 6 on Naval Station Norfolk; Moved "dead-stick" to Berth 1E in NASSCO shipyard on May 5.
# [DDG79] [Rota] [Aug. 25] July 10, USS Oscar Austin moored at Berth 2, Pier 1 on Naval Station Rota; Moved to Pier 3 for a brief stop before moored at Berth 1, Pier 1 on Aug. 25.
# [DDG80] [Suez Canal] [Nov. 13] October 27, USS Roosevelt moored at    Berth 1/2, Pier 1 on Naval Station Rota; Underway again on Nov. 8; Transited the Strait of Gibraltar eastbound on Nov. 8; Transited the Suez Canal southbound on Nov. 13.
# [DDG81] [Rota] [Nov. 16] October 29, The Churchill moored at Berth 3/4, Pier 1 on Naval Station Rota; Moved to Pier 3 to refuel on Nov. 1; Departed Rota on Nov. 2; Transited the Anegada Passage southbound, in support of national tasking, on Nov. 16.
# [DDG82] [Mayport] [Nov. 14] November 13, USS Lassen moored at Wharf B3 on Naval Station Mayport after a one-day underway in the Jacksonville Op. Area; Underway again from Nov. 14-17.
# [DDG83] [Yokosuka] [Oct. 2] April 17, USS Howard moved "dead-stick" from HMP East to   Dry Dock #5 on Fleet Activities Yokosuka; Undocked and moored at HMP East on Oct. 2.?
# [DDG84] [Rota] [Nov. 10] October 9, USS Bulkeley moored at Berth 1/2, Pier 1 on Naval Station Rota; Day-long underway  on Oct. 21; Moved to Berth 2, Pier 1, outboard the USS Arleigh Burke (DDG 51), on Oct. 27; Moved to Berth 4, Pier 1 on  Nov. 3; Moved to Berth 1/2, Pier 1 on Nov. 10.
# [DDG85] [Yokosuka] [Nov. 12] October 13, USS McCampbell moored at HMP West on Fleet Activities Yokosuka after a three-day underway for sea trials, following a nine-month Selected Restricted Availability (SRA); Anchored at A-12 for ammo onload on Nov. 3; Moored at Berth 12 on Nov. 7; Underway again from Nov. 12-14.
# [DDG86] [Busan] [Nov. 5] October 20, The Shoup participated in a PHOTOEX, as part of  Annual Exercise (ANNUALEX) 25, while underway off the south coast of Japan; Conducted operations in Sagami Wan from Oct. 21-25; Moored at Berth 2 in Busan Naval Base, ROK, from Nov. 5-9.
# [DDG87] [Mayport] [October 16] October 16, The Mason moored at Wharf B1 on Naval Station Mayport.
# [DDG88] [Yokosuka] [November 21] November 21, USS Preble moored at Berth 3 on Fleet Activities Yokosuka following a 46-day patrol.
# [DDG89] [San Diego] [November 17] November 17, USS Mustin moored at Berth 2, Pier 3 on Naval Base San Diego.
# [DDG90] [San Diego] [November 7] November 7, The Chafee moored at Berth 6, Pier 3 on Naval Base San Diego after a four-day underway in the SOCAL Op. Area.
# [DDG91] [San Diego] [Nov. 18] August 25, The Pinckney moored at Naval Weapons Station Seal Beach for an eight-day ammo onload; Returned home on Sept. 5; Underway again from Nov. 18-20.
# [DDG92] [San Diego] [Nov. 13] May ?, 2025 USS Monsen undocked and moored pierside on Continental Maritime of San Diego (CMSD) shipyard; Moved "dead-stick" to Berth 6, Pier 8 in Naval Base San Diego on Nov. 13.
# [DDG93] [San Diego] [July 23] November 20, USS Chung-Hoon recently undocked and moored at Berth 4 on NASSCO shipyard; Moved "dead-stick"  to Berth 6, Pier 10 in Naval Base San Diego on July 23, 2025.
# [DDG94] [Norfolk] [Nov. 21] October 6,  The Nitze moored at Berth 2, Pier 7 on Naval Station Norfolk after a six-day underway in the Virginia Capes Op. Area; Underway again from Oct. 20-27; Anchored at Explosives Anchorage G2 for a brief stop before underway on Nov. 18; Returned home on Nov. 21.
# [DDG95] [Norfolk] [Nov. 21] October 14, 2025 USS James E. Williams moved "dead-stick" from Earl Industries shipyard to Berth 1, Pier 7 on Naval Station Norfolk; Underway for sea trials, following a 23-month DMP, on Nov. 18; Moored at Berth 5, Pier 7 on Nov. 21.
# [DDG96] [Caribbean Sea] [November 17] November 17, The Bainbridge conducted a replenishment-at-sea with the USNS Kanawha (T-AO 196), while underway approx. 120 n.m. south of Puerto Rico.
# [DDG97] [San Diego] [2025] June ?, 2025 USS Halsey undocked and moored pierside at Continental Maritime of San Diego (CMSD) shipyard.
# [DDG98] [Underway / Unknown] [Oct. 1] October 7, DDG 98 recently moored at Berth 47, Southern General Cargo Terminal in Jeddah Islamic Port to refuel; Inport Jeddah again for upkeep from Oct. 1?-2?.
# [DDG99] [Atlantic Ocean] [Nov. 10] From November 4-7, the Farragut conducted operations at the Atlantic Undersea Test and Evaluation Center (AUTEC) range, off the east coast of Andros Island, Bahamas; Moored at Wharf B2 on Nov. 10.
# [DDG100] [Seattle] [March 8] January 22, 2025 USS Kidd moored at Berth 1, Alpha Pier on Naval Station Everett after a one-day underway in the Strait of Juan de Fuca; Moved "dead-stick" to Pier 6W, Vigor Shipyards in Seattle on Feb. 20; Entered the Dry Dock Evolution on March 8.
# [DDG101] [Western Pacific] [Nov. 18] October 21, The Gridley moored at Berth 5, RSS Singapura - Changi Naval Base in Singapore for a two-day port call; Conducted a replenishment-at-sea with the USNS Washington Chambers (T-AKE 11), while underway southwest of Luzon, on Nov. 1; Conducted a replenishment-at-sea with the USNS Amelia Earhart (T-AKE 6), while underway off the coast of Brunei, on Nov. 11; Transited the San Bernardino Strait northbound on Nov. 18.
# [DDG102] [San Diego] [Nov. 13] September 22, The Sampson moored at Berth 6, Pier 3 on Naval Base San Diego for a week-long port call; Moored at NFF for a brief stop to refuel on Oct. 6 and 16th; Brief stop at NFF again before moored at Berth 6, Pier 3 from Oct. 28- Nov. 4; Moored at NFF for a brief stop to refuel on Nov. 13.
# [DDG103] [Norfolk] [2025] , USS Truxtun moored at Berth 2, Pier 6 on Naval Station Norfolk following a nearly seven-month deployment in the U.S. 5th and 6th Fleet AoR.
# [DDG104] [San Diego] [2025] , USS Sterett moored at Berth 1, Pier 7 on Naval Base San Diego following an extended nine-month deployment in the U.S. 5th and 7th Fleet AoR.
# [DDG105] [Underway / Unknown] [Nov. 18] November 14, USS Dewey moored at Pyeongtaek Naval Base, Republic of Korea, for a four-day port call; Participated in a Maritime Counter Special Operations Exercise (MCSOFEX), in the Yellow Sea, from Nov. 18-20.
# [DDG106] [Caribbean Sea] [Nov. 14] October 17, The Stockdale conducted a replenishment-at-sea with the USNS Kanawha (T-AO 196), while underway south of Puerto Rico; Moored at Berth 8 in Port of Ponce from Nov. 7-9; Transited eastbound, approx. 20 n.m. south of Curacao, overseas territory of Netherlands, on Nov. 13; Transited northbound, approx. 20 n.m. east of Orchila Island, Venezuela, just after midnight on Nov. 14.
# [DDG107] [Caribbean Sea] [October 26] October 26, USS Gravely moored at Berth 6W, King's Wharf in Port of Port of Spain, Trinidad and Tobago, for a four-day visit.
# [DDG108] [Singapore] [Oct. 17] September 24, USS Wayne E. Meyer moored at Berth 5, East Terminal in Port of Karachi, Pakistan, for a two-day visit; Transited the Malacca Strait southbound from Oct. 16-17; Transited the Strait of Singapore eastbound on Oct. 17.
# [DDG109] [Mayport] [2025] , USS Jason Dunham moored at Wharf F1 on Naval Station Mayport following a three-month deployment in the U.S. 4th Flleet AoR.
# [DDG110] [Pearl Harbor] [Oct. 6] October 3, USS William P. Lawrence moored at Pier B17 on Joint Base Pearl Harbor-Hickam; Moored at Wharf W4 for ammo offload from Oct. 6-9.
# [DDG111] [Pacific Ocean] [2025] , USS Spruance departed San Diego for a scheduled deployment.
# [DDG112] [Underway / Unknown] [Nov. 21] November 17, The Michael Monsoor moored at Wharf W4, Naval Magazine Lualualei for ammo onload; Moored at Wharf B26 on Nov. 21.
# [DDG113] [Pacific Ocean] [2025] , USS John Finn moored at Berth 7 on Fleet Activities Yokosuka following a four-and-a-half month Indo-Pacific deployment.
# [DDG114] [Pacific Ocean] [Aug. 9] , USS Ralph Johnson moored at Berth 12 on Fleet Activities Yokosuka following an extended six-month Indo-Pacific patrol; Anchored at A-10 for ammo offload on Aug. 6; Anchored at A-10 again after a day-long underway off the coast of Honshu on Aug. 7; Moored at Berth 8 on Aug. 9.
# [DDG115] [Yokosuka] [Nov. 19] November 18, USS Rafael Peralta moored  at HMP West on  Fleet Activities Yokosuka; Underway again on Nov. 19.
# [DDG116] [Norfolk] [Nov. 19] October 6, DDG 116 moored at  Weapons Pier R3 North on Naval Weapons Station Yorktown for a four-day ammo onload; Moored at Berth 5, Pier 5 on Naval Station Norfolk from Oct. 10-14; Moored at Wharf A2 on Oct. 17; Brief underway  on Nov. 19.
# [DDG117] [Rota] [Nov. 14] October 20, The Paul Ignatius moored at Berth 3, Pier 1 on Naval Station Rota; Underway again on Nov. 10; Moored at Berth 3/4, Pier 1 on Nov. 13; Underway again from Nov. 14-15.
# [DDG118] [San Diego] [Feb. 7] January 10, 2025 USS Daniel Inouye  departed homeport in support of the USS Nimitz (CVN 68) CSG's COMPTUEX, in the SOCAL Op. Area; Moored at NFF, Naval Base Point Loma for a brief stop to refuel on Jan. 17; Moored at Wharf W4, Naval Magazine Lualualei for ammo offload on Feb. 3; Moved to Pier B18 on Feb. 7.
# [DDG119] [Mayport] [November 14] November 14, USS Delbert D. Black moored at Wharf D1 on Naval Station Mayport.
# [DDG120] [San Diego] [Nov. 19] November 10, The Carl M. Levin moored at NFF on Naval Base Point Loma for a brief stop to refuel; Moored at Berth 1, Pier 7 in Naval Base San Diego for a brief stop on Nov. 19.
# [DDG121] [Pearl Harbor] [Sept. 24] August 29, DDG 121 moored at N/S/O Mike Pier on Naval Base Point Loma for a five-day port call; Moored at Wharf 3 in Port Hueneme, Calif., from Sept. 4-1?;  Made a brief stop at Wharf B25 before moored at Wharf B22 in Pearl Harbor on Sept. 18; Moored at Wharf W4 for ammo onload on Sept. 24; Moored at Wharf B24 on 2?.
# [DDG122] [Mayport] [Nov. 20] October 22,  USS John Basilone moored outboard the USS Thomas Hudner at Wharf A2 on Naval Station Mayport after a two-day underway in the Jacksonville Op. Area; Moved to Wharf D1 on Oct. 27; Underway again on Nov. 10; Moored at Wharf C2 on Nov. 20.
# [DDG123] [Western Pacific] [Nov. 18] October 10, The Higbee moored at Bravo Wharf on Navy Support Facility Diego Garcia, British Indian Ocean Teritory, for a brief stop to refuel; Transited the Malacca Strait southbound from Oct. 16-17; Transited the Strait of Singapore eastbound on Oct. 17; Transited the San Bernardino Strait northbound on Nov. 18.
# [DDG125] [Pearl Harbor] [November 18] November 18, USS Jack H. Lucas moored at Pier H3 on Joint Base Pearl Harbor-Hickam for a brief stop to refuel.
# [DDG1000] [Pascagoula] [December 6] December 6, USS Zumwalt  undocked and mored at Ingalls West Bank Yard South Wharf.
# [DDG1001] [San Diego] [Nov. 1] October 27, The Michael Monsoor moored at NFF on Naval Base Point Loma for a brief stop to refuel before underway in the SOCAL Op. Area; Moored at NWS Seal Beach for ammo offload from Oct. 28-31; Moored at Berth 6, Pier 12 on Nov. 1.
# [DDG1002] [Underway / Unknown] [2023] No status found.
#
# ==========================================================================================
# SUCCESS: Report saved to '/content/fleet_status.csv'
# ==========================================================================================

# %%
"""
US NAVY FLEET MAPPER (v13.0 - Complete Surface Fleet)

Visualizes the output of the 'Fleet Tracker' (fleet_status.csv).
"""

import pandas as pd
import folium
import os
from folium.plugins import MarkerCluster, BeautifyIcon

# --- CONFIGURATION ---
INPUT_FILE = "fleet_status.csv"
OUTPUT_FILE = "fleet_map.html"

# --- COORDINATE DICTIONARY ---
LOCATION_COORDS = {
    # US Ports / Shipyards
    "norfolk": [36.96, -76.30],
    "san diego": [32.68, -117.18],
    "mayport": [30.39, -81.42],
    "pearl harbor": [21.35, -157.97],
    "bremerton": [47.55, -122.64],
    "kitsap": [47.70, -122.70],
    "everett": [47.98, -122.22],
    "seattle": [47.60, -122.33],
    "port angeles": [48.12, -123.43],
    "portland, or": [45.56, -122.71],
    "groton": [41.39, -72.08],
    "kings bay": [30.80, -81.53],
    "pascagoula": [30.34, -88.56],
    "mobile, al": [30.69, -88.04],
    "pensacola": [30.35, -87.27],
    "panama city": [30.15, -85.75],
    "marinette": [45.10, -87.62],
    "orange, tx": [30.09, -93.73],
    "philadelphia": [39.89, -75.17],
    "charleston, sc": [32.85, -79.97],
    "port canaveral": [28.41, -80.60],
    "maine": [43.90, -69.80], # Bath/General Maine

    # Foreign Ports
    "yokosuka": [35.29, 139.66],
    "yokohama": [35.44, 139.63],
    "sasebo": [33.16, 129.71],
    "busan": [35.10, 129.11],
    "guam": [13.44, 144.65],
    "saipan": [15.21, 145.72],
    "okinawa": [26.30, 127.80],
    "singapore": [1.30, 103.85],
    "klang": [3.00, 101.38],
    "brunei": [4.53, 114.72],
    "manila": [14.59, 120.97],
    "subic": [14.80, 120.27],
    "thailand": [12.60, 100.90],
    "bahrain": [26.22, 50.61],
    "dubai": [25.26, 55.30],
    "qatar": [25.35, 51.55],
    "duqm": [19.66, 57.70],
    "diego garcia": [-7.31, 72.41],
    "australia": [ -32.05, 115.74], # Perth
    "rota": [36.62, -6.35],
    "italy": [40.84, 14.25], # Naples/Gaeta general
    "gaeta": [41.21, 13.58],
    "souda bay": [35.48, 24.07],
    "malta": [35.90, 14.51],

    # Regions
    "south china sea": [12.00, 114.00],
    "philippine sea": [20.00, 130.00],
    "western pacific": [15.00, 135.00],
    "sea of japan": [40.00, 135.00],
    "persian gulf": [27.00, 51.00],
    "arabian sea": [15.00, 65.00],
    "red sea": [20.00, 38.00],
    "gulf of oman": [24.00, 58.00],
    "gulf of aden": [12.00, 48.00],
    "mediterranean": [35.00, 18.00],
    "caribbean sea": [15.00, -75.00],
    "north sea": [56.00, 3.00],
    "strait of gibraltar": [35.95, -5.60],
    "suez canal": [30.60, 32.33],
    "panama canal": [9.10, -79.67],
    "bab el-mandeb": [12.58, 43.33],

    # Oceans
    "atlantic ocean": [33.00, -60.00],
    "pacific ocean": [25.00, -150.00],
    "indian ocean": [-5.00, 80.00],
    "underway / unknown": [0.0, 0.0]
}

def get_location_key_and_coords(text):
    if not isinstance(text, str): return "unknown", LOCATION_COORDS["underway / unknown"]
    text = text.lower()
    if text in LOCATION_COORDS: return text, LOCATION_COORDS[text]
    for location in LOCATION_COORDS:
        if location in text: return location, LOCATION_COORDS[location]
    return "unknown", LOCATION_COORDS["underway / unknown"]

def generate_map():
    print(f"{'='*60}")
    print(f"OFFICIAL FLEET MAPPER (Total Fleet)")
    print(f"{'='*60}")

    if not os.path.exists(INPUT_FILE):
        print(f"ERROR: {INPUT_FILE} not found. Run fleet_scraper.py first.")
        return

    locations_db = {}

    def add_to_db(loc_key, coords, ship_data):
        if loc_key in ["newport news", "portsmouth", "little creek"]: loc_key = "norfolk"
        if loc_key not in locations_db:
            locations_db[loc_key] = {"coords": coords, "ships": []}
        locations_db[loc_key]["ships"].append(ship_data)

    print(f"Reading fleet data from {INPUT_FILE}...")
    df = pd.read_csv(INPUT_FILE)

    mapped_count = 0

    for _, row in df.iterrows():
        loc_tag = str(row['Location'])
        loc_key, coords = get_location_key_and_coords(loc_tag)
        hull = row['Hull'].upper()

        # Ship Class Determination
        if "CVN" in hull: s_type = "CVN"
        elif any(x in hull for x in ["LHA", "LHD", "LPD", "LSD"]): s_type = "AMPHIB"
        elif "LCC" in hull: s_type = "COMMAND"
        elif "CG" in hull: s_type = "CRUISER"
        elif "LCS" in hull: s_type = "LCS"
        elif "AS" in hull: s_type = "TENDER"
        elif "ESB" in hull: s_type = "ESB"
        elif "DDG" in hull: s_type = "DESTROYER"
        else: s_type = "OTHER"

        add_to_db(loc_key, coords, {
            "hull": hull,
            "date": row['Date'],
            "status": row['Status Sentence'],
            "type": s_type
        })
        mapped_count += 1

    m = folium.Map(location=[25, 0], zoom_start=3, tiles="CartoDB positron")

    for loc_key, data in locations_db.items():
        coords = data['coords']
        ships = data['ships']

        # Icon Priority
        if any(s['type'] == "CVN" for s in ships): color, icon = "blue", "plane"
        elif any(s['type'] == "AMPHIB" for s in ships): color, icon = "red", "anchor"
        elif any(s['type'] == "COMMAND" for s in ships): color, icon = "purple", "flag"
        elif any(s['type'] == "DESTROYER" for s in ships): color, icon = "black", "rocket"
        elif any(s['type'] == "CRUISER" for s in ships): color, icon = "darkgreen", "crosshairs"
        elif any(s['type'] == "ESB" for s in ships): color, icon = "cadetblue", "ship"
        elif any(s['type'] == "TENDER" for s in ships): color, icon = "gray", "wrench"
        else: color, icon = "orange", "ship"

        if coords == [0.0, 0.0]: color, icon, loc_label = "gray", "question", "LOCATION UNKNOWN"
        else: loc_label = loc_key.title()

        hull_list = [s['hull'] for s in ships]
        tooltip_text = f"{loc_label}: {len(ships)} Ships"

        popup_html = f"""
        <div style="font-family:sans-serif; width:350px; overflow-y:auto; max-height:300px;">
            <h4 style="margin-bottom:5px; border-bottom:2px solid {color};">{loc_label.upper()}</h4>
            <table style="width:100%; font-size:11px; border-collapse:collapse;">
        """

        # Sort: CVN > LCC > Amphib > CG > DDG > ESB > AS > LCS
        ships.sort(key=lambda x: {"CVN":1, "COMMAND":2, "AMPHIB":3, "CRUISER":4, "DESTROYER":5, "ESB":6, "TENDER":7, "LCS":8, "OTHER":9}.get(x['type'], 99))

        for s in ships:
            t_col = {"CVN": "darkblue", "AMPHIB": "darkred", "COMMAND": "purple", "CRUISER": "green", "DESTROYER": "black", "LCS": "orange", "ESB": "teal", "TENDER": "gray"}.get(s['type'], "black")
            popup_html += f"""
            <tr style="border-bottom:1px solid #eee;">
                <td style="padding:5px; vertical-align:top; width:70px;"><b style="color:{t_col};">{s['hull']}</b></td>
                <td style="padding:5px;"><span style="color:gray; font-size:9px;">{s['date']}</span><br>{s['status'][:200]}</td>
            </tr>
            """
        popup_html += "</table></div>"

        folium.Marker(location=coords, popup=folium.Popup(popup_html, max_width=370), tooltip=tooltip_text, icon=folium.Icon(color=color, icon=icon, prefix='fa')).add_to(m)

    title_html = '''
             <div style="position: fixed; top: 10px; right: 10px; width: 180px; height: 220px; z-index:9999; font-size:11px; background-color: white; opacity: 0.9; padding: 10px; border-radius: 5px; border: 1px solid grey;">
                 <b>US Navy Fleet Overview</b><br><hr style="margin:5px 0;">
                 <i class="fa fa-plane" style="color:blue; margin-right:5px;"></i> Carrier Group<br>
                 <i class="fa fa-flag" style="color:purple; margin-right:5px;"></i> Command Ship<br>
                 <i class="fa fa-anchor" style="color:red; margin-right:5px;"></i> Amphibious Group<br>
                 <i class="fa fa-rocket" style="color:black; margin-right:5px;"></i> Destroyer (DDG)<br>
                 <i class="fa fa-ship" style="color:cadetblue; margin-right:5px;"></i> Sea Base (ESB)<br>
                 <i class="fa fa-crosshairs" style="color:darkgreen; margin-right:5px;"></i> Cruiser<br>
                 <i class="fa fa-wrench" style="color:gray; margin-right:5px;"></i> Tender (AS)<br>
                 <i class="fa fa-ship" style="color:orange; margin-right:5px;"></i> LCS / Other
             </div>
             '''
    m.get_root().html.add_child(folium.Element(title_html))
    m.save(OUTPUT_FILE)
    print(f"\nSUCCESS: Map generated at '{os.path.abspath(OUTPUT_FILE)}'")
    print(f"Mapped {mapped_count} ships to {len(locations_db)} locations.")

if __name__ == "__main__":
    generate_map()
# Out:
# ============================================================
# OFFICIAL FLEET MAPPER (Total Fleet)
# ============================================================
# Reading fleet data from fleet_status.csv...
#
# SUCCESS: Map generated at '/content/fleet_map.html'
# Mapped 163 ships to 29 locations.
